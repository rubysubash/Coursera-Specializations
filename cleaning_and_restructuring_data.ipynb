# %% [markdown]
# <a href="https://colab.research.google.com/github/rubysubash/Coursera-Specializations/blob/master/cleaning_and_restructuring_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://ichef.bbci.co.uk/news/660/cpsprodpb/143A0/production/_112184828_gettyimages-939290830.jpg)
#
# Obesity is a medical condition in which excess body fat has accumulated to an extent that it may have a negative effect on health. People are generally considered obese when their body mass index (BMI), a measurement obtained by dividing a person's weight by the square of the person's height, is over 30 ; the range 25–30  is defined as overweight. Obesity increases the likelihood of various diseases and conditions, particularly cardiovascular diseases, type 2 diabetes, obstructive sleep apnea, certain types of cancer, osteoarthritis, and depression.
#
# Here we look at the WHO adults' obesity dataset for each country from 1975 to 2016.
#
# The metric used is percentage of adults who have Body Mass Index (BMI) >= 30.
#
# ### **Update**:
#
# Thanks to [Ran.Krish](https://www.kaggle.com/rankirsh) and [AndrewHou](https://www.kaggle.com/andrewhou) for the explanation about the estimate range within brackets in the data.
#
# I'll quote them here
#
# > It is probably a confidance interval, ill try to explain.
# Researchers can't know exactly what is the obesity rate so they compute a confidance interval (usually 95%), it means that we are 95% confident that the obesity rate in every sample (of the same size) in this specific country will be between 0.2 and 1.1
#
# > Thanks ,you did a great explaining.
# Let me just add this for people without Statistical backgrounds.
# Researchers aren't able to ask every person to compute the exact number of Obesity %, it would cost a lot of money.
# so they just use sampling methods, for example, ask 10% people of every cities ( saturated sampling).
# 0.5 is the point estimation.
# 0.2~1.1 is the interval estimation, which means researchers are 95% or so confident that the REAL obesity% is between 0.2~1.1

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/obesity-among-adults-by-country-19752016/data.csv
# /kaggle/input/obesity-among-adults-by-country-19752016/obesity-cleaned.csv

# %% [markdown]
# **Loading the data**

# %%
df=pd.read_csv('/kaggle/input/obesity-among-adults-by-country-19752016/data.csv')

# %% [markdown]
# Let us see what the data from the downloaded csv file looks like:

# %%
df.head()
# Out:
#     Unnamed: 0                                               2016  \
# 0          NaN  Prevalence of obesity among adults, BMI &Great...
# 1          NaN                                         18+  years
# 2      Country                                         Both sexes
# 3  Afghanistan                                      5.5 [3.4-8.1]
# 4      Albania                                   21.7 [17.0-26.7]
#
#                                               2016.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      3.2 [1.3-6.4]
# 4                                   21.6 [14.8-29.0]
#
#                                               2016.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                     7.6 [4.3-12.4]
# 4                                   21.8 [15.3-28.9]
#
#                                                 2015  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      5.2 [3.3-7.7]
# 4                                   21.1 [16.6-26.0]
#
#                                               2015.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      3.0 [1.3-6.0]
# 4                                   20.9 [14.4-28.1]
#
#                                               2015.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                     7.3 [4.1-11.8]
# 4                                   21.3 [15.1-28.1]
#
#                                                 2014  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      4.9 [3.1-7.3]
# 4                                   20.5 [16.2-25.1]
#
#                                               2014.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      2.8 [1.2-5.6]
# 4                                   20.2 [13.9-27.3]
#
#                                               2014.2  ...  \
# 0  Prevalence of obesity among adults, BMI &Great...  ...
# 1                                         18+  years  ...
# 2                                             Female  ...
# 3                                     7.0 [4.0-11.3]  ...
# 4                                   20.8 [14.9-27.4]  ...
#
#                                               1978.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                      0.9 [0.3-2.2]
# 4                                     9.1 [4.6-15.5]
#
#                                                 1977  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      0.6 [0.2-1.2]
# 4                                     6.8 [4.0-10.7]
#
#                                               1977.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      0.2 [0.0-0.7]
# 4                                      4.8 [2.0-9.3]
#
#                                               1977.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                      0.9 [0.3-2.1]
# 4                                     8.9 [4.3-15.4]
#
#                                                 1976  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      0.5 [0.2-1.1]
# 4                                     6.7 [3.8-10.6]
#
#                                               1976.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      0.2 [0.0-0.7]
# 4                                      4.6 [1.8-9.2]
#
#                                               1976.2  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                      0.8 [0.2-2.0]
# 4                                     8.8 [4.1-15.4]
#
#                                                 1975  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                         Both sexes
# 3                                      0.5 [0.2-1.1]
# 4                                     6.5 [3.6-10.5]
#
#                                               1975.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                               Male
# 3                                      0.2 [0.0-0.6]
# 4                                      4.4 [1.7-9.2]
#
#                                               1975.2
# 0  Prevalence of obesity among adults, BMI &Great...
# 1                                         18+  years
# 2                                             Female
# 3                                      0.8 [0.2-2.0]
# 4                                     8.6 [3.9-15.4]
#
# [5 rows x 127 columns]

# %% [markdown]
# Check the dimensions of the dataframe df

# %%
df.shape
# Out:
# (198, 127)

# %% [markdown]
# One of the headers is not clearly visible, let's print it

# %%
df.iloc[0,1]
# Out:
# 'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)'

# %% [markdown]
# What are the column titles?

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '2016', '2016.1', '2016.2', '2015', '2015.1', '2015.2',
#        '2014', '2014.1', '2014.2',
#        ...
#        '1978.2', '1977', '1977.1', '1977.2', '1976', '1976.1', '1976.2',
#        '1975', '1975.1', '1975.2'],
#       dtype='object', length=127)

# %% [markdown]
# Let's drop the unnecessary top 3 rows

# %%
df.drop([0,1,2],inplace=True)
df.head()
# Out:
#     Unnamed: 0              2016            2016.1            2016.2  \
# 3  Afghanistan     5.5 [3.4-8.1]     3.2 [1.3-6.4]    7.6 [4.3-12.4]
# 4      Albania  21.7 [17.0-26.7]  21.6 [14.8-29.0]  21.8 [15.3-28.9]
# 5      Algeria  27.4 [22.5-32.7]  19.9 [13.6-27.1]  34.9 [27.6-42.7]
# 6      Andorra  25.6 [20.1-31.3]  25.9 [18.0-34.3]  25.3 [17.7-33.7]
# 7       Angola    8.2 [5.1-12.2]     4.0 [1.6-7.9]   12.1 [6.8-19.0]
#
#                2015            2015.1            2015.2              2014  \
# 3     5.2 [3.3-7.7]     3.0 [1.3-6.0]    7.3 [4.1-11.8]     4.9 [3.1-7.3]
# 4  21.1 [16.6-26.0]  20.9 [14.4-28.1]  21.3 [15.1-28.1]  20.5 [16.2-25.1]
# 5  26.7 [21.9-31.8]  19.2 [13.2-26.1]  34.2 [27.1-41.7]  26.0 [21.4-30.9]
# 6  25.4 [20.1-31.0]  25.5 [17.8-33.8]  25.2 [17.7-33.4]  25.2 [20.0-30.7]
# 7    7.9 [4.9-11.7]     3.8 [1.5-7.3]   11.6 [6.5-18.2]    7.5 [4.7-11.2]
#
#              2014.1            2014.2  ...            1978.2             1977  \
# 3     2.8 [1.2-5.6]    7.0 [4.0-11.3]  ...     0.9 [0.3-2.2]    0.6 [0.2-1.2]
# 4  20.2 [13.9-27.3]  20.8 [14.9-27.4]  ...    9.1 [4.6-15.5]   6.8 [4.0-10.7]
# 5  18.5 [12.7-25.0]  33.6 [26.7-40.7]  ...   11.8 [6.5-18.6]   7.4 [4.3-11.3]
# 6  25.2 [17.6-33.3]  25.1 [17.8-33.1]  ...  17.5 [10.9-25.3]  14.0 [9.6-19.1]
# 7     3.6 [1.4-6.9]   11.1 [6.2-17.5]  ...     1.6 [0.5-3.7]    0.9 [0.3-2.0]
#
#             1977.1            1977.2             1976           1976.1  \
# 3    0.2 [0.0-0.7]     0.9 [0.3-2.1]    0.5 [0.2-1.1]    0.2 [0.0-0.7]
# 4    4.8 [2.0-9.3]    8.9 [4.3-15.4]   6.7 [3.8-10.6]    4.6 [1.8-9.2]
# 5    3.1 [1.2-6.2]   11.4 [6.2-18.4]   7.2 [4.1-11.1]    2.9 [1.1-6.1]
# 6  10.7 [5.6-17.4]  16.9 [10.4-24.8]  13.5 [9.1-18.6]  10.2 [5.2-16.9]
# 7    0.3 [0.0-0.9]     1.5 [0.4-3.6]    0.9 [0.3-2.0]    0.3 [0.0-0.9]
#
#             1976.2             1975          1975.1           1975.2
# 3    0.8 [0.2-2.0]    0.5 [0.2-1.1]   0.2 [0.0-0.6]    0.8 [0.2-2.0]
# 4   8.8 [4.1-15.4]   6.5 [3.6-10.5]   4.4 [1.7-9.2]   8.6 [3.9-15.4]
# 5  11.1 [5.8-18.2]   6.9 [3.9-10.9]   2.8 [1.0-6.0]  10.7 [5.5-18.0]
# 6  16.4 [9.8-24.4]  12.9 [8.6-18.1]  9.7 [4.7-16.3]  15.8 [9.2-23.9]
# 7    1.4 [0.4-3.5]    0.8 [0.3-1.9]   0.2 [0.0-0.8]    1.4 [0.4-3.4]
#
# [5 rows x 127 columns]

# %% [markdown]
# As we can see, the titles which have **.1** and **.2** as suffix are **'Male'** and **'Female'** respectively and the other one with only the year (e.g., 2016) is overall obesity for both sexes.
#
# Also, reset the indices:

# %%
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# `drop=True` is used to delete the 'index' column which is created if we do `df.reset_index()` without `drop=True`

# %%
df.head()
# Out:
#     Unnamed: 0              2016            2016.1            2016.2  \
# 0  Afghanistan     5.5 [3.4-8.1]     3.2 [1.3-6.4]    7.6 [4.3-12.4]
# 1      Albania  21.7 [17.0-26.7]  21.6 [14.8-29.0]  21.8 [15.3-28.9]
# 2      Algeria  27.4 [22.5-32.7]  19.9 [13.6-27.1]  34.9 [27.6-42.7]
# 3      Andorra  25.6 [20.1-31.3]  25.9 [18.0-34.3]  25.3 [17.7-33.7]
# 4       Angola    8.2 [5.1-12.2]     4.0 [1.6-7.9]   12.1 [6.8-19.0]
#
#                2015            2015.1            2015.2              2014  \
# 0     5.2 [3.3-7.7]     3.0 [1.3-6.0]    7.3 [4.1-11.8]     4.9 [3.1-7.3]
# 1  21.1 [16.6-26.0]  20.9 [14.4-28.1]  21.3 [15.1-28.1]  20.5 [16.2-25.1]
# 2  26.7 [21.9-31.8]  19.2 [13.2-26.1]  34.2 [27.1-41.7]  26.0 [21.4-30.9]
# 3  25.4 [20.1-31.0]  25.5 [17.8-33.8]  25.2 [17.7-33.4]  25.2 [20.0-30.7]
# 4    7.9 [4.9-11.7]     3.8 [1.5-7.3]   11.6 [6.5-18.2]    7.5 [4.7-11.2]
#
#              2014.1            2014.2  ...            1978.2             1977  \
# 0     2.8 [1.2-5.6]    7.0 [4.0-11.3]  ...     0.9 [0.3-2.2]    0.6 [0.2-1.2]
# 1  20.2 [13.9-27.3]  20.8 [14.9-27.4]  ...    9.1 [4.6-15.5]   6.8 [4.0-10.7]
# 2  18.5 [12.7-25.0]  33.6 [26.7-40.7]  ...   11.8 [6.5-18.6]   7.4 [4.3-11.3]
# 3  25.2 [17.6-33.3]  25.1 [17.8-33.1]  ...  17.5 [10.9-25.3]  14.0 [9.6-19.1]
# 4     3.6 [1.4-6.9]   11.1 [6.2-17.5]  ...     1.6 [0.5-3.7]    0.9 [0.3-2.0]
#
#             1977.1            1977.2             1976           1976.1  \
# 0    0.2 [0.0-0.7]     0.9 [0.3-2.1]    0.5 [0.2-1.1]    0.2 [0.0-0.7]
# 1    4.8 [2.0-9.3]    8.9 [4.3-15.4]   6.7 [3.8-10.6]    4.6 [1.8-9.2]
# 2    3.1 [1.2-6.2]   11.4 [6.2-18.4]   7.2 [4.1-11.1]    2.9 [1.1-6.1]
# 3  10.7 [5.6-17.4]  16.9 [10.4-24.8]  13.5 [9.1-18.6]  10.2 [5.2-16.9]
# 4    0.3 [0.0-0.9]     1.5 [0.4-3.6]    0.9 [0.3-2.0]    0.3 [0.0-0.9]
#
#             1976.2             1975          1975.1           1975.2
# 0    0.8 [0.2-2.0]    0.5 [0.2-1.1]   0.2 [0.0-0.6]    0.8 [0.2-2.0]
# 1   8.8 [4.1-15.4]   6.5 [3.6-10.5]   4.4 [1.7-9.2]   8.6 [3.9-15.4]
# 2  11.1 [5.8-18.2]   6.9 [3.9-10.9]   2.8 [1.0-6.0]  10.7 [5.5-18.0]
# 3  16.4 [9.8-24.4]  12.9 [8.6-18.1]  9.7 [4.7-16.3]  15.8 [9.2-23.9]
# 4    1.4 [0.4-3.5]    0.8 [0.3-1.9]   0.2 [0.0-0.8]    1.4 [0.4-3.4]
#
# [5 rows x 127 columns]

# %% [markdown]
# Set the first column title to be **Country**

# %%
df.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

# %%
df.head()
# Out:
#        Country              2016            2016.1            2016.2  \
# 0  Afghanistan     5.5 [3.4-8.1]     3.2 [1.3-6.4]    7.6 [4.3-12.4]
# 1      Albania  21.7 [17.0-26.7]  21.6 [14.8-29.0]  21.8 [15.3-28.9]
# 2      Algeria  27.4 [22.5-32.7]  19.9 [13.6-27.1]  34.9 [27.6-42.7]
# 3      Andorra  25.6 [20.1-31.3]  25.9 [18.0-34.3]  25.3 [17.7-33.7]
# 4       Angola    8.2 [5.1-12.2]     4.0 [1.6-7.9]   12.1 [6.8-19.0]
#
#                2015            2015.1            2015.2              2014  \
# 0     5.2 [3.3-7.7]     3.0 [1.3-6.0]    7.3 [4.1-11.8]     4.9 [3.1-7.3]
# 1  21.1 [16.6-26.0]  20.9 [14.4-28.1]  21.3 [15.1-28.1]  20.5 [16.2-25.1]
# 2  26.7 [21.9-31.8]  19.2 [13.2-26.1]  34.2 [27.1-41.7]  26.0 [21.4-30.9]
# 3  25.4 [20.1-31.0]  25.5 [17.8-33.8]  25.2 [17.7-33.4]  25.2 [20.0-30.7]
# 4    7.9 [4.9-11.7]     3.8 [1.5-7.3]   11.6 [6.5-18.2]    7.5 [4.7-11.2]
#
#              2014.1            2014.2  ...            1978.2             1977  \
# 0     2.8 [1.2-5.6]    7.0 [4.0-11.3]  ...     0.9 [0.3-2.2]    0.6 [0.2-1.2]
# 1  20.2 [13.9-27.3]  20.8 [14.9-27.4]  ...    9.1 [4.6-15.5]   6.8 [4.0-10.7]
# 2  18.5 [12.7-25.0]  33.6 [26.7-40.7]  ...   11.8 [6.5-18.6]   7.4 [4.3-11.3]
# 3  25.2 [17.6-33.3]  25.1 [17.8-33.1]  ...  17.5 [10.9-25.3]  14.0 [9.6-19.1]
# 4     3.6 [1.4-6.9]   11.1 [6.2-17.5]  ...     1.6 [0.5-3.7]    0.9 [0.3-2.0]
#
#             1977.1            1977.2             1976           1976.1  \
# 0    0.2 [0.0-0.7]     0.9 [0.3-2.1]    0.5 [0.2-1.1]    0.2 [0.0-0.7]
# 1    4.8 [2.0-9.3]    8.9 [4.3-15.4]   6.7 [3.8-10.6]    4.6 [1.8-9.2]
# 2    3.1 [1.2-6.2]   11.4 [6.2-18.4]   7.2 [4.1-11.1]    2.9 [1.1-6.1]
# 3  10.7 [5.6-17.4]  16.9 [10.4-24.8]  13.5 [9.1-18.6]  10.2 [5.2-16.9]
# 4    0.3 [0.0-0.9]     1.5 [0.4-3.6]    0.9 [0.3-2.0]    0.3 [0.0-0.9]
#
#             1976.2             1975          1975.1           1975.2
# 0    0.8 [0.2-2.0]    0.5 [0.2-1.1]   0.2 [0.0-0.6]    0.8 [0.2-2.0]
# 1   8.8 [4.1-15.4]   6.5 [3.6-10.5]   4.4 [1.7-9.2]   8.6 [3.9-15.4]
# 2  11.1 [5.8-18.2]   6.9 [3.9-10.9]   2.8 [1.0-6.0]  10.7 [5.5-18.0]
# 3  16.4 [9.8-24.4]  12.9 [8.6-18.1]  9.7 [4.7-16.3]  15.8 [9.2-23.9]
# 4    1.4 [0.4-3.5]    0.8 [0.3-1.9]   0.2 [0.0-0.8]    1.4 [0.4-3.4]
#
# [5 rows x 127 columns]

# %% [markdown]
# Here comes the important part.
#
# What I personally want to do right here is have 4 columns, namely, **Country, Year, Obesity (%) and Sex** for easier Exploratory Data Analysis and Visualizations.
#
# I used `df.melt()` for the same. It essentially "unpivots" the data from a wide format to a long format.
#
# Documentation for the same can be viewed [here](https://pandas.pydata.org/docs/reference/api/pandas.melt.html)

# %%
ndf = df.melt('Country', var_name='Year', value_name='Obesity (%)')
ndf[['Year', 'Sex']] = ndf['Year'].str.split('.', expand=True)

# %%
ndf.head(10)
# Out:
#                Country  Year       Obesity (%)   Sex
# 0          Afghanistan  2016     5.5 [3.4-8.1]  None
# 1              Albania  2016  21.7 [17.0-26.7]  None
# 2              Algeria  2016  27.4 [22.5-32.7]  None
# 3              Andorra  2016  25.6 [20.1-31.3]  None
# 4               Angola  2016    8.2 [5.1-12.2]  None
# 5  Antigua and Barbuda  2016  18.9 [13.8-24.6]  None
# 6            Argentina  2016  28.3 [23.4-33.5]  None
# 7              Armenia  2016  20.2 [15.7-24.8]  None
# 8            Australia  2016  29.0 [25.3-32.9]  None
# 9              Austria  2016  20.1 [15.9-24.6]  None

# %% [markdown]
# Now we sort our dataset by **Country** and by **Year**

# %%
ndf=ndf.sort_values(by=['Country','Year'])

# %% [markdown]
# Resetting the indices:

# %%
ndf=ndf.reset_index(drop=True)

# %%
ndf.head()
# Out:
#        Country  Year    Obesity (%)   Sex
# 0  Afghanistan  1975  0.5 [0.2-1.1]  None
# 1  Afghanistan  1975  0.2 [0.0-0.6]     1
# 2  Afghanistan  1975  0.8 [0.2-2.0]     2
# 3  Afghanistan  1976  0.5 [0.2-1.1]  None
# 4  Afghanistan  1976  0.2 [0.0-0.7]     1

# %% [markdown]
# As we can see we need to change the 3 distinct values in **'Sex'** column.
#
# We do this as follows:

# %%
ndf['Sex']=ndf['Sex'].map({None: 'Both sexes', '1': 'Male', '2':'Female'})

# %% [markdown]
# Let's split the obesity data to create another column which has the age-standardized estimate

# %%
ndf['Age standardized estimate']=ndf['Obesity (%)'].apply(lambda x:x.split()[1])

# %%
ndf['Obesity (%)']=ndf['Obesity (%)'].apply(lambda x:x.split()[0])

# %%
ndf.head()
# Out:
#        Country  Year Obesity (%)         Sex Age standardized estimate
# 0  Afghanistan  1975         0.5  Both sexes                 [0.2-1.1]
# 1  Afghanistan  1975         0.2        Male                 [0.0-0.6]
# 2  Afghanistan  1975         0.8      Female                 [0.2-2.0]
# 3  Afghanistan  1976         0.5  Both sexes                 [0.2-1.1]
# 4  Afghanistan  1976         0.2        Male                 [0.0-0.7]

# %% [markdown]
# Voila! We fixed the downloaded dataset as we wanted.
#
# Let us save the output .csv file.

# %%
ndf.to_csv('/kaggle/working/obesity-clean-split.csv')
